# %% [markdown]
# # Talking Data User Demographics
#
# ## 1. Business Problem
#
# ### 1.1. Problem Overview

# %% [markdown]
# Nothing is more comforting than being greeted by your favorite drink just as you walk through the door of the corner café. While a thoughtful barista knows you take a macchiato every Wednesday morning at 8:15, it’s much more difficult in a digital space for your preferred brands to personalize your experience.
#
# TalkingData, China’s largest third-party mobile data platform, understands that everyday choices and behaviors paint a picture of who we are and what we value. Currently, TalkingData is seeking to leverage behavioral data from more than 70% of the 500 million mobile devices active daily in China to help its clients better understand and interact with their audiences.
#
# In this competition, Kagglers are challenged to build a model predicting users’ demographic characteristics based on their app usage, geolocation, and mobile device properties. Doing so will help millions of developers and brand advertisers around the world pursue data-driven marketing efforts which are relevant to their users and catered to their preferences.
#
# <b>Source</b> : https://www.kaggle.com/c/talkingdata-mobile-user-demographics/overview

# %% [markdown]
# ### 1.2. Real-world/Business objectives and constraints

# %% [markdown]
# * No low-latency requirement.
# * Probability of a data-point belonging to each class is needed.

# %% [markdown]
# ## 2. Machine Learning Problem Formulation
#
# ### 2.1. Data Overview

# %% [markdown]
# The Data is collected from TalkingData SDK integrated within mobile apps TalkingData serves under the service term between TalkingData and mobile app developers.
#
# **Source:** https://www.kaggle.com/c/talkingdata-mobile-user-demographics/data
#
# 1. **gender_age_train.csv, gender_age_test.csv** - the training and test set
#      group: this is the target variable we are going to predict
# 2. **events.csv, app_events.csv** - when a user uses TalkingData SDK, the event gets logged in this data. Each event has an event id, location (lat/long), and the event corresponds to a list of apps in app_events.
#     timestamp: when the user is using an app with TalkingData SDK
# 3. **app_labels.csv** - apps and their labels, the label_id's can be used to join with label_categories
# 4. **label_categories.csv** - apps' labels and their categories in text
# 5. **phone_brand_device_model.csv** - device ids, brand, and models
#     phone_brand: note that the brands are in Chinese (translation courtesy of user fromandto)
#
#      * 三星 samsung
#
#      * 天语 Ktouch
#
#      * 海信 hisense
#
#      *  联想 lenovo
#
#      * 欧比 obi
#
#      * 爱派尔 ipair
#
#      * 努比亚 nubia
#
#      * 优米 youmi
#
#      * 朵唯 dowe
#
#      * 黑米 heymi
#
#      * 锤子 hammer
#
#      * 酷比魔方 koobee
#
#      * 美图 meitu
#
#      * 尼比鲁 nibilu
#
#      * 一加 oneplus
#
#      * 优购 yougo
#
#      * 诺基亚 nokia
#
#      * 糖葫芦 candy
#
#      * 中国移动 ccmc
#
#      * 语信 yuxin
#
#      * 基伍 kiwu
#
#      * 青橙 greeno
#
#      * 华硕 asus
#
#      * 夏新 panosonic
#
#      * 维图 weitu
#
#      * 艾优尼 aiyouni
#
#      * 摩托罗拉 moto
#
#      * 乡米 xiangmi
#
#      * 米奇 micky
#
#      * 大可乐 bigcola
#
#      * 沃普丰 wpf
#
#      * 神舟 hasse
#
#      * 摩乐 mole
#
#      * 飞秒 fs
#
#      * 米歌 mige
#
#      * 富可视 fks
#
#      * 德赛 desci
#
#      * 梦米 mengmi
#
#      * 乐视 lshi
#
#      * 小杨树 smallt
#
#      * 纽曼 newman
#
#      * 邦华 banghua
#
#      * E派 epai
#
#      * 易派 epai
#
#      * 普耐尔 pner
#
#      * 欧新 ouxin
#
#      * 西米 ximi
#
#      * 海尔 haier
#
#      * 波导 bodao
#
#      * 糯米 nuomi
#
#      * 唯米 weimi
#
#      * 酷珀 kupo
#
#      * 谷歌 google
#
#      * 昂达 ada
#
#      * 聆韵 lingyun

# %% [markdown]
# ### 2.2 Mapping Real-World Problem to Machine-Learning Problem
#
# #### 2.2.1. Type of ML Problem

# %% [markdown]
# 1. It is a Multi-Class Classification Problem.
# 2. The 12 classes to predict are:
#    * F23-
#    * F24-26
#    * F27-28
#    * F29-32
#    * F33-42
#    * F43+
#    * M22-
#    * M23-26
#    * M27-28
#    * M29-31
#    * M32-38
#    * M39+

# %% [markdown]
# #### 2.2.2. Performance Metric

# %% [markdown]
# <b> Source: </b> https://www.kaggle.com/c/talkingdata-mobile-user-demographics/overview/evaluation
#
# 1. Multi-class Log-loss
# 2. Confusion Matrix

# %% [markdown]
# #### 2.2.3. Machine Learing Objectives and Constraints

# %% [markdown]
# <b> Objective: </b> Predict the probability of each data-point belonging to each of the 12 classes.

# %% [markdown]
# <b> Constraints: </b>
# * Class probabilities are needed.
# * No Latency constraints.

# %% [markdown]
# # Contents <br>
# 1. <b> Exploratory Data Analysis </b> <br>
#     1.1. Gender - Age Data <br>
#     1.2. Phone Brands and Device Models <br>
#     1.3. App Labels <br>
#     1.4. Events <br>
# 2. <b> Process Flow Diagram </b> <br>
# 3. <b> Feature Engineering </b> <br>
#     3.1. One Hot Encoding for Phone Brands <br>
#     3.2. One Hot Encoding for Device Models <br>
#     3.3. One Hot Encoding for app_id <br>
#     3.4. One Hot Encoding for app_labels <br>
#     3.5. Tfidf Vectorizer for Events Hour <br>
#     3.6. Tfidf Vectorizer for Events Day <br>
#     3.7. Tfidf Vectorizer for Apps Active <br>
# 4. <b> Classification Model for Gender </b> <br>
#     4.1. Features used for Classification Model <br>
#     4.2. Target variable <br>
#     4.3. Logistic Regression for Gender Classification <br>
#     4.4. Neural Network for Gender Classification <br>
#     4.5. Representing Results <br>
#     4.6. Final Predictions for Gender <br>
# 5. <b> Regression Model for Age </b> <br>
#     5.1. Features used for Regression Model <br>
#     5.2. Target variable <br>
#     5.3. Linear Regression Model for Age prediction <br>
#     5.4. Preprocessing the Age Feature <br>
# 6. <b> Final Classification Model </b> <br>
#     6.1. Features used <br>
#     6.2. Target variable <br>
#     6.3. Logistic Regression Model <br>
#     6.4. Neural Network 1 <br>
#     6.5. Neural Network 2 <br>
#     6.6. Representing Results <br>
# 7. <b> Ensemble Modeling </b> <br>
# 8. <b> Kaggle Submission </b> <br>
#     8.1. Kaggle Scores <br>
#     8.2. Private Leaderboard <br>
#     8.3. Public Leaderboard <br>
# 9. <b> Conclusion </b> <br>
# 10. <b> References </b> <br>

# %% [markdown]
# # 1. Exploratory Data Analysis

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import re
import time
import warnings
warnings.filterwarnings("ignore")
# %matplotlib inline

# %% [markdown]
# ## 1.1. Gender - Age Data

# %% [markdown]
# ## Gender Age Train

# %%
#Loading the train_data
train_data = pd.read_csv('Data/gender_age_train.csv')

# %%
train_data.head()
# Out:
#              device_id gender  age   group
# 0 -8076087639492063270      M   35  M32-38
# 1 -2897161552818060146      M   35  M32-38
# 2 -8260683887967679142      M   35  M32-38
# 3 -4938849341048082022      M   30  M29-31
# 4   245133531816851882      M   30  M29-31

# %% [markdown]
# ### Checking if the train data is balanced or imbalanced

# %%
#Getting the value counts of the group column in train_data to compare the values of different age groups
train_data.group.value_counts().plot.bar()
plt.xlabel('Age Group')
plt.ylabel('Number of people')
# Out:
# Text(0, 0.5, 'Number of people')

# %%
# Getting the value counts of the gender column to compare the total amount of data consisting of men and women
train_data.gender.value_counts().plot.bar()
plt.xlabel('Gender')
plt.ylabel('Number')
# Out:
# Text(0, 0.5, 'Number')

# %% [markdown]
# ## Observations for Gender Analysis
# 1. From the above plot, it can be observed that its an imbalanced dataset.
# 2. The number of females is less than the number of males.

# %% [markdown]
# ### Statistical Analysis of Males

# %%
# Query to get all the data consisting of men
males = train_data.loc[train_data.gender=='M']

# %%
males
# Out:
#                  device_id gender  age   group
# 0     -8076087639492063270      M   35  M32-38
# 1     -2897161552818060146      M   35  M32-38
# 2     -8260683887967679142      M   35  M32-38
# 3     -4938849341048082022      M   30  M29-31
# 4       245133531816851882      M   30  M29-31
# ...                    ...    ...  ...     ...
# 74640  4682031842235089751      M   30  M29-31
# 74641 -9178703742877135986      M   30  M29-31
# 74642   180946546684162312      M   20    M22-
# 74643  1390702386071991851      M   37  M32-38
# 74644    89181010588227347      M   25  M23-26
#
# [47904 rows x 4 columns]

# %%
# Getting the statistical description of males
males.age.describe()
# Out:
# count    47904.000000
# mean        31.052939
# std          9.454653
# min          1.000000
# 25%         25.000000
# 50%         29.000000
# 75%         35.000000
# max         90.000000
# Name: age, dtype: float64

# %% [markdown]
# ## Observations for Male Count Plot
#
# 1. The groups like 'M23-26' and 'M32-38' has the highest count in the data.
# 2. The lowest count is for 'M27-28' and for the other groups the distribution if fairly balanced among men.

# %% [markdown]
# ### Statistical Analysis of Females

# %%
# Query to get data consisting of only women
females = train_data.loc[train_data.gender=='F']

# %%
females
# Out:
#                  device_id gender  age   group
# 5     -1297074871525174196      F   24  F24-26
# 9      1596610250680140042      F   36  F33-42
# 11     7477216237379271436      F   37  F33-42
# 12     2478205222798310601      F   28  F27-28
# 15     1508636020748379883      F   28  F27-28
# ...                    ...    ...  ...     ...
# 74626  8012242415081116163      F   30  F29-32
# 74627 -7513478293429751074      F   56    F43+
# 74630 -2510601842775405069      F   22    F23-
# 74631 -2572857383593438598      F   21    F23-
# 74638  5645813107043557722      F   51    F43+
#
# [26741 rows x 4 columns]

# %%
# Getting the statistical description of women
females.age.describe()
# Out:
# count    26741.000000
# mean        32.050596
# std         10.539967
# min         10.000000
# 25%         25.000000
# 50%         29.000000
# 75%         37.000000
# max         96.000000
# Name: age, dtype: float64

# %% [markdown]
# ## Observations for Female Count Plot
#
# 1. The highest count is for 'F33-42' and lowest if for 'F27-28'.
# 2. As the females data is less, the distribution for the count of females is quite uneven and less balanced than men

# %% [markdown]
# ## Observations for statistical analysis of gender
#
# 1. As we can see that the count of males is 47904 and the count of females if 26741.
# 2. The rest of the measures like mean, standard deviation, percentiles are same for the both genders.

# %%
# Getting the number of unique device ids in train data
print("The number of unique device ids for train data is :",len(np.unique(train_data['device_id'].values)))
# Out:
# The number of unique device ids for train data is : 74645

# %% [markdown]
# ## Gender Age Test

# %%
test_data = pd.read_csv('Data/gender_age_test.csv')

# %%
test_data.head()
# Out:
#              device_id
# 0  1002079943728939269
# 1 -1547860181818787117
# 2  7374582448058474277
# 3 -6220210354783429585
# 4 -5893464122623104785

# %%
print("The number of unique device ids for test data is :",len(np.unique(test_data['device_id'].values)))
# Out:
# The number of unique device ids for test data is : 112071

# %% [markdown]
# ## 1.2 Phone Brand and Device Model

# %%
# Reading the phone brand and device models data
phone_data = pd.read_csv('Data/phone_brand_device_model.csv',encoding='utf-8')

# %%
# Dropping the duplicates if they exist
phone_data = phone_data.drop_duplicates('device_id',keep='first')

# %%
phone_data.head()
# Out:
#              device_id phone_brand   device_model
# 0 -8890648629457979026          小米             红米
# 1  1277779817574759137          小米           MI 2
# 2  5137427614288105724          三星      Galaxy S4
# 3  3669464369358936369       SUGAR           时尚手机
# 4 -5019277647504317457          三星  Galaxy Note 2

# %%
# Getting the number of unique phone brands and device models
print("Number of unique phone brands :",len(np.unique(phone_data['phone_brand'].values)))
print("Number of unqiue device models :",len(np.unique(phone_data['device_model'].values)))
# Out:
# Number of unique phone brands : 131
# Number of unqiue device models : 1599

# %% [markdown]
# * As the number of phone brands is less, we can manually map the chinese names into english names.

# %%
# Code taken from -> https://render.githubusercontent.com/view/ipynb?commit=34ae63e73154d6a91af7d993d8aa24a6d6552022&enc_url=&nwo=yiqingyang75%2Fkaggle-TalkingData-Mobile-User-Demographics&path=py%2FTalkingData_MobileUser_Demographics_Concise.ipynb&repository_id=117802001&repository_type=Repository#phone-brand
# Converting the Chinese names into English for better data analysis observations

phone_brand = list(["索尼", "中兴", "金立", "魅族", "华为", "酷派", "小米", "MIL", "PPTV", "ZOYE", "Lovme", "SUGAR", "LOGO", 
                    "TCL", "ZUK", "LG", "HTC", "vivo", "OPPO", "E派", "一加", "三星","中国移动","乐视","乡米","优米","优购",
                    "努比亚","华硕","唯米","基伍","夏新","大可乐","天语","富可视","小杨树","尼比鲁","德赛","摩乐","摩托罗拉",
                    "昂达","易派","普耐尔","朵唯","梦米","欧新","欧比","沃普丰","波导","海信","海尔","爱派尔","神舟","米奇",
                    "米歌","糖葫芦","糯米","纽曼","维图","美图","聆韵","联想","艾优尼","西米","语信","诺基亚","谷歌","邦华",
                    "酷比魔方","酷珀","锤子","青橙","飞秒","黑米"])
eng_phone_brand = list(["Sony", "ZTE", "gionee", "meizu", "huawei", "coolpad", "MI", "MIL", "PPTV", "ZOYE", "Lovme", "SUGAR",
                        "LOGO", "TCL", "ZUK", "LG", "HTC", "vivo", "OPPO", "epai","oneplus", "samsung", "ccmc", "lshi", 
                        "xiangmi", "youmi", "yougo", "nubia", "asus", "weimi", "kiwu", "panosonic", "bigcola", "Ktouch",
                        "fks", "smallt", "nibilu", "desci", "mole", "moto", "ada", "epai", "pner", "dowe", "mengmi", "ouxin",
                        "obi", "wpf", "bodao", "hisense", "haier", "ipair", "hasse", "micky", "mige", "candy", "nuomi", 
                        "newman", "weitu", "meitu", "lingyun", "lenovo", "aiyouni", "ximi", "yuxin", "nokia", "google", 
                        "banghua", "koobee", "kupo", "hammer", "greeno", "fs", "heymi"])

phone_brand_trans = pd.DataFrame({'phone_brand': phone_brand, 'eng_phone_brand': eng_phone_brand})

# %%
phone_brand_trans.head()
# Out:
#   phone_brand eng_phone_brand
# 0          索尼            Sony
# 1          中兴             ZTE
# 2          金立          gionee
# 3          魅族           meizu
# 4          华为          huawei

# %%
# Merging the translated phone brands with phone data
phone_data = phone_data.merge(phone_brand_trans, how = "left", on="phone_brand")

# %%
# Dropping the phone brand which consists of chinese names
phone_data = phone_data.drop('phone_brand',1)

# %%
phone_data.head()
# Out:
#              device_id   device_model eng_phone_brand
# 0 -8890648629457979026             红米              MI
# 1  1277779817574759137           MI 2              MI
# 2  5137427614288105724      Galaxy S4         samsung
# 3  3669464369358936369           时尚手机           SUGAR
# 4 -5019277647504317457  Galaxy Note 2         samsung

# %% [markdown]
# ### Getting the most popular brands

# %%
# Getting the counts of values of each brand
brand_values = phone_data["eng_phone_brand"].value_counts().reset_index()
brand_values
# Out:
#       index  eng_phone_brand
# 0        MI            43107
# 1   samsung            34191
# 2    huawei            32465
# 3      vivo            14342
# 4      OPPO            14239
# ..      ...              ...
# 68     mole                5
# 69     PPTV                5
# 70       fs                2
# 71      MIL                2
# 72     ZOYE                1
#
# [73 rows x 2 columns]

# %%
# Finding the popular brands
brand_values = phone_data["eng_phone_brand"].value_counts().reset_index().head(10)
ax = sns.barplot(x = brand_values["eng_phone_brand"], y = brand_values["index"])
ax.set_xlabel('Counts of brands')
ax.set_ylabel('Brands')
# Out:
# Text(0, 0.5, 'Brands')

# %%
# Getting the percentage of market each brand holds
brand_values = phone_data["eng_phone_brand"].value_counts().reset_index()

top_cnt = 0
total_cnt = 0
for i in range(10):
    top_cnt += brand_values['eng_phone_brand'][i]

for i in range(len(brand_values)):
    total_cnt += brand_values['eng_phone_brand'][i]
    
print("Counts of top 10 brands =",top_cnt)
print("Counts of all brands =",total_cnt)
print("Percentage of devices top brands account for =",(top_cnt/total_cnt)*100,"%")
print("-"*60)

for i in range(len(brand_values)):
    print(str(brand_values['index'][i])+" accounts for "+str((brand_values['eng_phone_brand'][i]/total_cnt)*100)+" % of the total devices.")
# Out:
# Counts of top 10 brands = 170732
# Counts of all brands = 185532
# Percentage of devices top brands account for = 92.0229394390186 %
# ------------------------------------------------------------
# MI accounts for 23.2342668650152 % of the total devices.
# samsung accounts for 18.428626867602354 % of the total devices.
# huawei accounts for 17.498329129206823 % of the total devices.
# vivo accounts for 7.730202876053727 % of the total devices.
# OPPO accounts for 7.674686846473924 % of the total devices.
# meizu accounts for 6.368712674902442 % of the total devices.
# coolpad accounts for 4.517819028523381 % of the total devices.
# lenovo accounts for 3.6392643856585387 % of the total devices.
# gionee accounts for 1.4892309682426752 % of the total devices.
# HTC accounts for 1.4417997973395424 % of the total devices.
# ZTE accounts for 1.127568290106289 % of the total devices.
# lshi accounts for 1.0327059483000236 % of the total devices.
# ...

# %% [markdown]
# ## Observations for brands
#
# 1. The top 10 brands account for more than 90% of all the devices.
# 2. The most popular brands are MI, Samsung and Huawei and they account for almost 60% of the total devices.
# 3. After the top 10 brands, each of the rest of the brands account for less than 1% of the total market.

# %% [markdown]
# ### Checking if there is a correlation between age and the phone brand

# %%
# Merging the phone data with train data to get the correlation between brands and age
merged_data = train_data.merge(phone_data, on='device_id',how='left')
merged_data.head()
# Out:
#              device_id gender  age   group device_model eng_phone_brand
# 0 -8076087639492063270      M   35  M32-38         MI 2              MI
# 1 -2897161552818060146      M   35  M32-38         MI 2              MI
# 2 -8260683887967679142      M   35  M32-38         MI 2              MI
# 3 -4938849341048082022      M   30  M29-31       红米note              MI
# 4   245133531816851882      M   30  M29-31         MI 3              MI

# %%
# Plotting the values to observe if there is any clear difference between age groups and phone brands
brand_values = phone_data["eng_phone_brand"].value_counts().reset_index().head(10)
plt.figure(figsize=(18,10))
sns.boxplot(x ="eng_phone_brand", y ="age", hue ="gender",
            data=merged_data.loc[merged_data["eng_phone_brand"].isin(list(brand_values["index"]))])
plt.axhline(merged_data["age"].median(),color = "red")
plt.ylim(0,70)
# Out:
# (0.0, 70.0)

# %% [markdown]
# ## Observations for relation between Age and Brands
#
# 1. Its clear from the boxplot that users who use Samsung, Huawei and Lenovo are mostly older.
# 2. Younger users tend to use Vivo and Meizu.

# %% [markdown]
# ### Checking if there are any brands that are specific to a certain gender

# %%
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.query.html
# Queries to get the male data and female data to distinguish between brands
female_brands = merged_data.query("gender == 'F'")
male_brands = merged_data.query("gender == 'M'")

# %%
# Counting the brands that are used by specific genders
brand_counts_male = female_brands['eng_phone_brand'].value_counts().reset_index().head(20)
brand_counts_female = male_brands['eng_phone_brand'].value_counts().reset_index().head(20)

# %%
# Plotting to see if any brand is popular among any gender
plt.figure(figsize=(15,5))

ind = np.arange(len(list(brand_counts_female['index'])))  
plot_1 = plt.bar(ind, brand_counts_male['eng_phone_brand'])
plot_2 = plt.bar(ind, brand_counts_female['eng_phone_brand'], bottom=brand_counts_male['eng_phone_brand'])

plt.xticks(ind, list(brand_counts_female['index']))
plt.xlabel('Brands')
plt.ylabel('Count')
plt.legend((plot_1,plot_2),('Men','Women'))
plt.show()

# %% [markdown]
# ## Observations for relation between Gender and Brands
#
# 1. From the readings, it can be seen that brands like MI, Huawei, Samsung, Meizu, Lenovo, ZTE, etc are popular among women.
# 2. For most of the other brands, the distribution is almost equal.

# %% [markdown]
# ### Getting the most popular device models

# %%
# Getting the counts of the device models
device_values = phone_data["device_model"].value_counts().reset_index()
device_values
# Out:
#                 index  device_model
# 0              红米note          7343
# 1                MI 3          5699
# 2               MI 2S          5301
# 3       Galaxy Note 3          5010
# 4                MI 4          4788
# ...               ...           ...
# 1594             木星一号             1
# 1595  G Pro Lite Dual             1
# 1596             E820             1
# 1597            小辣椒X5             1
# 1598              G10             1
#
# [1599 rows x 2 columns]

# %%
# PLotting the top 15 device models with the counts of their total values
device_values = phone_data["device_model"].value_counts().reset_index().head(15)
ax = sns.barplot(x = device_values["device_model"], y = device_values["index"])
ax.set_xlabel('Counts of devices')
ax.set_ylabel('Devices')
# Out:
# Text(0, 0.5, 'Devices')

# %% [markdown]
# ## Observations
#
# 1. Unlike the top brands, the top device models only account for about 25% of the total market.
# 2. Th9s is because there are about 1600 device models.
# 3. The devices such as Redmi Note, MI 3, MI 2S and Galaxy Note 3 are the top device models preferred by users.

# %% [markdown]
# ### Checking if there is a correlation between age and the device models

# %%
# Plotting the vales to observe the correlation between age and models
device_values = phone_data["device_model"].value_counts().reset_index().head(15)
plt.figure(figsize=(18,10))
sns.boxplot(x ="device_model", y ="age", hue ="gender",
            data=merged_data.loc[merged_data["device_model"].isin(list(device_values["index"]))])
plt.axhline(merged_data["age"].median(),color = "red")
plt.ylim(0,70)
# Out:
# (0.0, 70.0)

# %% [markdown]
# ## Observations for relations between Age and Device models
#
# 1. It can be observed that Mate 7, Galaxy Note 3, Honor Play 4x, Galaxy Note 2 and Galaxy S3 are used by older users from the above box plot.
# 2. Other devices such as Redmi NOTE, MI 2S are popular among the younger generation

# %% [markdown]
# ### Checking if the device models are specific to a gender

# %%
# Getting the value counts of the device models used by a specific gender
device_counts_male = female_brands['device_model'].value_counts().reset_index().head(15)
device_counts_female = male_brands['device_model'].value_counts().reset_index().head(15)

# %%
# Plotting to see if any model is popular among any gender
plt.figure(figsize=(15,5))

ind = np.arange(len(list(device_counts_female['index'])))  
plot_1 = plt.bar(ind, device_counts_male['device_model'])
plot_2 = plt.bar(ind, device_counts_female['device_model'], bottom=device_counts_male['device_model'])

plt.xticks(ind, list(device_counts_female['index']))
plt.xlabel('Brands')
plt.ylabel('Count')
plt.legend((plot_1,plot_2),('Men','Women'))
plt.show()

# %% [markdown]
# ## Observations
#
# 1. From the readings, it can be seen that brands like Redmi Note, Mate 6, Huawei Glory 6, etc are popular among women.
# 2. For most of the other brands like MI 3, MI 2S, Galaxy Note 3, etc the distribution is more for women as well but the difference isn't as much as the previous bands.

# %% [markdown]
# ## 1.3. App Labels

# %%
# Reading the app labels and label categories data
label_categories = pd.read_csv('Data/label_categories.csv')
app_labels = pd.read_csv('Data/app_labels.csv')

# %%
label_categories.head()
# Out:
#    label_id           category
# 0         1                NaN
# 1         2     game-game type
# 2         3   game-Game themes
# 3         4     game-Art Style
# 4         5  game-Leisure time

# %%
app_labels.head()
# Out:
#                 app_id  label_id
# 0  7324884708820027918       251
# 1 -4494216993218550286       251
# 2  6058196446775239644       406
# 3  6058196446775239644       407
# 4  8694625920731541625       406

# %%
# Merging the app labels data with label categories
merged_data_labels = app_labels.merge(label_categories,on="label_id", how='left')

# %%
merged_data_labels.head()
# Out:
#                 app_id  label_id         category
# 0  7324884708820027918       251          Finance
# 1 -4494216993218550286       251          Finance
# 2  6058196446775239644       406          unknown
# 3  6058196446775239644       407  DS_P2P net loan
# 4  8694625920731541625       406          unknown

# %%
# Getting the counts of values of top 20 app categories
app_counts = merged_data_labels["category"].value_counts().reset_index().head(20)
ax = sns.barplot(x = app_counts["category"], y = app_counts["index"])
ax.set_xlabel('Counts of app categories')
ax.set_ylabel('Categories')
# Out:
# Text(0, 0.5, 'Categories')

# %% [markdown]
# ## Observations for App Categories
#
# 1. There are about 473 total app categories.
# 2. The top 10 app categories out of the total app categories account for about 68.116% of the total apps.
# 3. The top app categories include Industry tag, custom label, Tencent accounts, Game Accounts, Property Industry, etc.

# %% [markdown]
# ## 1.4 Events

# %%
# Reading the events and app events data
events = pd.read_csv('Data/events.csv')
app_events = pd.read_csv('Data/app_events.csv')

# %%
events.head()
# Out:
#    event_id            device_id            timestamp  longitude  latitude
# 0         1    29182687948017175  2016-05-01 00:55:25     121.38     31.24
# 1         2 -6401643145415154744  2016-05-01 00:54:12     103.65     30.97
# 2         3 -4833982096941402721  2016-05-01 00:08:05     106.60     29.70
# 3         4 -6815121365017318426  2016-05-01 00:06:40     104.27     23.28
# 4         5 -5373797595892518570  2016-05-01 00:07:18     115.88     28.66

# %%
app_events
# Out:
#           event_id               app_id  is_installed  is_active
# 0                2  5927333115845830913             1          1
# 1                2 -5720078949152207372             1          0
# 2                2 -1633887856876571208             1          0
# 3                2  -653184325010919369             1          1
# 4                2  8693964245073640147             1          1
# ...            ...                  ...           ...        ...
# 32473062   3252948  6607018907660377991             1          1
# 32473063   3252948  6602285879264922467             1          1
# 32473064   3252948  4348659952760821294             1          1
# 32473065   3252948  -995726944612374565             1          1
# 32473066   3252948  2306067392090419925             1          1
#
# [32473067 rows x 4 columns]

# %%
plt.figure()
devices_events = np.in1d(train_data['device_id'].values,events['device_id'].values)
pd.Series(devices_events).map({True:'Events',False:'No_Events'}).value_counts().plot.pie()
plt.title("Devices with events and no events (Train Data)")
plt.show()

# %%
print("Devices with Events Percentage in Train Data: ",(list(devices_events).count(True)/len(devices_events))*100," %")
print("Devices with No Events Percentage in Train Data: ",(list(devices_events).count(False)/len(devices_events))*100, " %")
# Out:
# Devices with Events Percentage in Train Data:  31.22647196731194  %
# Devices with no Events Percentage in Train Data:  68.77352803268806  %

# %%
plt.figure()
devices_events = np.in1d(test_data['device_id'].values,events['device_id'].values)
pd.Series(devices_events).map({True:'Events',False:'No_Events'}).value_counts().plot.pie()
plt.title("Devices with events and no events (Test Data)")
plt.show()

# %%
print("Devices with Events Percentage in Test Data: ",(list(devices_events).count(True)/len(devices_events))*100," %")
print("Devices with No Events Percentage in Test Data: ",(list(devices_events).count(False)/len(devices_events))*100, " %")
# Out:
# Devices with Events Percentage in Test Data:  31.403306832275966  %
# Devices with No Events Percentage in Test Data:  68.59669316772403  %

# %% [markdown]
# ## Observations for devices with and without events
#
# 1. About 69% of the devices in both train and test data don't have any events and 31% of the devices have events.

# %%
# Merging the train data with events data
merged_data = train_data.merge(
                  events.merge(app_events, on='event_id', how='inner'), on='device_id', how='inner')\
                        .drop(columns=['longitude','latitude'],axis=1)\
                        .merge(merged_data_labels, on='app_id').drop(columns=['app_id','event_id','label_id'],axis=1)

# %%
merged_data
# Out:
#                     device_id gender  age   group            timestamp  \
# 0        -8260683887967679142      M   35  M32-38  2016-05-01 14:23:37
# 1        -8260683887967679142      M   35  M32-38  2016-05-01 14:23:37
# 2        -8260683887967679142      M   35  M32-38  2016-05-01 14:23:37
# 3         8761770737926125955      F   22    F23-  2016-05-04 06:56:52
# 4         8761770737926125955      F   22    F23-  2016-05-04 06:56:52
# ...                       ...    ...  ...     ...                  ...
# 78844327 -5256657731298498979      M   26  M23-26  2016-05-02 08:25:21
# 78844328 -5256657731298498979      M   26  M23-26  2016-05-02 08:25:21
# 78844329 -5256657731298498979      M   26  M23-26  2016-05-02 08:25:21
# 78844330 -5256657731298498979      M   26  M23-26  2016-05-02 08:25:21
# 78844331 -4071460957162948519      F   27  F27-28  2016-05-07 12:14:55
#
#           is_installed  is_active               category
# 0                    1          0             Services 1
# ...

# %%
# Query to get all the Males data from the merged data
males = merged_data.loc[merged_data.gender=='M'].drop(columns=['is_installed','is_active','gender'],axis=1)

# %%
males
# Out:
#                     device_id  age   group            timestamp  \
# 0        -8260683887967679142   35  M32-38  2016-05-01 14:23:37
# 1        -8260683887967679142   35  M32-38  2016-05-01 14:23:37
# 2        -8260683887967679142   35  M32-38  2016-05-01 14:23:37
# 6          966127256155632917   27  M27-28  2016-05-01 12:15:46
# 7          966127256155632917   27  M27-28  2016-05-01 12:15:46
# ...                       ...  ...     ...                  ...
# 78844326 -5256657731298498979   26  M23-26  2016-05-02 08:25:21
# 78844327 -5256657731298498979   26  M23-26  2016-05-02 08:25:21
# 78844328 -5256657731298498979   26  M23-26  2016-05-02 08:25:21
# 78844329 -5256657731298498979   26  M23-26  2016-05-02 08:25:21
# 78844330 -5256657731298498979   26  M23-26  2016-05-02 08:25:21
#
#                        category
# 0                    Services 1
# 1         Property Industry 2.0
# 2                  Industry tag
# 6                    Services 1
# ...

# %%
# Checking the top 15 app categories used by males
males_category = males["category"].value_counts().reset_index().head(15)
ax = sns.barplot(x = males_category["category"], y = males_category["index"])
ax.set_xlabel('Counts of males')
ax.set_ylabel('Category')
# Out:
# Text(0, 0.5, 'Category')

# %%
males_group = males[['category','group']]

# %%
males_group
# Out:
#                        category   group
# 0                    Services 1  M32-38
# 1         Property Industry 2.0  M32-38
# 2                  Industry tag  M32-38
# 6                    Services 1  M27-28
# 7         Property Industry 2.0  M27-28
# ...                         ...     ...
# 78844326                 pursue  M23-26
# 78844327            comfortable  M23-26
# 78844328           Industry tag  M23-26
# 78844329  Property Industry new  M23-26
# 78844330                service  M23-26
#
# [58612286 rows x 2 columns]

# %%
colors = ['red','blue','pink','yellow','green','purple','gold','orange','brown','black']

# %%
# Checking which age group among men dominates particular a app category
top_category_events = males_group['category'].value_counts().reset_index().head(10)['index']

plt.figure(figsize=(20,20))
sns.countplot(y="group", hue="category", data=males_group[males_group['category'].isin(top_category_events)], palette=colors)

# %% [markdown]
# ## Observations for events in Male Categories
#
# 1. The highest events are related to category of apps used by males are 'Industry Tag', 'Property Industry', 'Custom Label', 'Internet Banking', etc.
# 2. Older age groups tend to have events with apps related to Property, Industry, Services, etc. The younger age groups have less events related to these app categories.

# %%
# Getting the females data from the merged data
females = merged_data.loc[merged_data.gender=='F'].drop(columns=['is_installed','is_active','gender'],axis=1)

# %%
females
# Out:
#                     device_id  age   group            timestamp  \
# 3         8761770737926125955   22    F23-  2016-05-04 06:56:52
# 4         8761770737926125955   22    F23-  2016-05-04 06:56:52
# 5         8761770737926125955   22    F23-  2016-05-04 06:56:52
# 24       -4359019044606258375   23    F23-  2016-05-01 16:08:31
# 25       -4359019044606258375   23    F23-  2016-05-01 16:08:31
# ...                       ...  ...     ...                  ...
# 78844165 -6286275463231088361   23    F23-  2016-05-01 18:13:48
# 78844166 -6286275463231088361   23    F23-  2016-05-01 18:13:48
# 78844167 -6286275463231088361   23    F23-  2016-05-01 18:13:48
# 78844168 -6286275463231088361   23    F23-  2016-05-01 18:13:48
# 78844331 -4071460957162948519   27  F27-28  2016-05-07 12:14:55
#
#                        category
# 3                    Services 1
# 4         Property Industry 2.0
# 5                  Industry tag
# 24                   Services 1
# ...

# %%
# Checking which app categories are popular among females
females_category = females["category"].value_counts().reset_index().head(15)
ax = sns.barplot(x = females_category["category"], y = females_category["index"])
ax.set_xlabel('Counts of females')
ax.set_ylabel('Category')
# Out:
# Text(0, 0.5, 'Category')

# %%
females_group = females[['category','group']]

# %%
# Plotting the app categories that are popular among specific age groups of females
top_category_events = females_group['category'].value_counts().reset_index().head(10)['index']

plt.figure(figsize=(20,20))
sns.countplot(y="group", hue="category", data=females_group[females_group['category'].isin(top_category_events)], palette=colors)

# %% [markdown]
# ## Observations for events in female Categories
#
# 1. The highest events are related to category of apps used by females are 'Industry Tag', 'Property Industry', 'Custom Label', 'Internet Banking', etc. Its quite same to the events in events in Male Categories.
# 2. Older women tend to have events related to app categories such as Services, Propery, Industry, etc and Younger Women have less events related to these app categories.

# %% [markdown]
# # 2. Process Flow Diagram

# %%
from IPython.core.display import Image, display
display(Image('ProcessFlowDiagram.png'))

# %% [markdown]
# # 3. Feature Engineering

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import LabelEncoder
from sklearn.feature_extraction.text import TfidfVectorizer
from scipy.sparse import csr_matrix, hstack
from sklearn.preprocessing import StandardScaler,MinMaxScaler
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.calibration import CalibratedClassifierCV
from sklearn.metrics.classification import log_loss
from sklearn.linear_model import SGDClassifier
from sklearn.metrics import confusion_matrix
from sklearn.externals import joblib as jobl
from sklearn.manifold import TSNE
from tqdm import tqdm
from joblib import dump
from scipy import sparse
import numpy as np
from tqdm import tqdm
# %matplotlib inline
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\externals\joblib\__init__.py:15: DeprecationWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=DeprecationWarning)

# %%
# Reading the data
train_data = pd.read_csv('Data/gender_age_train.csv',index_col='device_id')
test_data = pd.read_csv('Data/gender_age_test.csv',index_col='device_id')
phone_data = pd.read_csv('Data/phone_brand_device_model.csv',encoding='utf-8')
# Get rid of duplicate device ids in phone
phone_data = phone_data.drop_duplicates('device_id',keep='first').set_index('device_id') 
label_categories = pd.read_csv('Data/label_categories.csv')
app_labels = pd.read_csv('Data/app_labels.csv')
events = pd.read_csv('Data/events.csv',parse_dates=['timestamp'], index_col='event_id')
app_events = pd.read_csv('Data/app_events.csv',usecols=['event_id','app_id','is_active'],dtype={'is_active':bool})

# %%
train_data['trainrow'] = np.arange(train_data.shape[0])
test_data['testrow'] = np.arange(test_data.shape[0])

# %% [markdown]
# # Approach
#
# 1. First, I am going to construct a CSR matrix for Phone Brand, Device Model, App_id, App_labels.
# 2. Then, a TFIDF vectorizer for App Events Hour, App Events Day, Apps Active.

# %% [markdown]
# ## 3.1. One Hot Encoding for Phone Brands

# %%
# Encoding the brands using LabelEncoder
enc_brand = LabelEncoder().fit(phone_data['phone_brand'])
phone_data['enc_brand'] = enc_brand.transform(phone_data['phone_brand'])

# %%
# As both of these dataframes have the same indices, the encoded brands will get assigned to the specific device_ids
train_data['brand'] = phone_data['enc_brand']
test_data['brand'] = phone_data['enc_brand']

# %%
# Getting the csr matrix from the encoded labels
Xtr_brand = csr_matrix((np.ones(train_data.shape[0]), 
                       (train_data.trainrow, train_data.brand)))
Xte_brand = csr_matrix((np.ones(test_data.shape[0]), 
                       (test_data.testrow, test_data.brand)))
print('The shape of Xtr_brand_no_events is', Xtr_brand.shape, 'the shape of Xte_brand_no_events is', Xte_brand.shape)
# Out:
# The shape of Xtr_brand_no_events is (74645, 131) the shape of Xte_brand_no_events is (112071, 131)

# %% [markdown]
# ## 3.2. One Hot Encoding for Device Models

# %%
# Encoding the device models using LabelEncoder same way as done for Brands
enc_model = LabelEncoder().fit(phone_data['device_model'])
phone_data['enc_model'] = enc_model.transform(phone_data['device_model'])

# %%
# As both of these dataframes have the same indices, the encoded brands will get assigned to the specific device_ids
train_data['model'] = phone_data['enc_model']
test_data['model'] = phone_data['enc_model']

# %%
# Getting the csr matrix from the encoded labels
Xtr_model = csr_matrix((np.ones(train_data.shape[0]), 
                       (train_data.trainrow, train_data.model)))
Xte_model = csr_matrix((np.ones(test_data.shape[0]), 
                       (test_data.testrow, test_data.model)))
print('The shape of Xtr_model_data is', Xtr_model.shape, 'the shape of Xte_model_data is', Xte_model.shape)
# Out:
# The shape of Xtr_model_data is (74645, 1599) the shape of Xte_model_data is (112071, 1599)

# %% [markdown]
# ## 3.3. One Hot Encoding for app_id

# %%
# For each device, we have to mark the apps that are installed in that device.  
# First, we will encode all the app_ids to integers using LabelEncoder. 
enc_apps = LabelEncoder().fit(app_events['app_id'])
app_events['enc_app'] = enc_apps.transform(app_events['app_id'])

# Then we merge the app_events with device_id column from the events dataframe grouping by device_id and encoded app_ids.
# Finally we merge it with trainrow and testrow columns to understand at which row we should put each device in features matrix.
deviceapps = (app_events.merge(events[['device_id']], how='left',left_on='event_id',right_index=True)
                       .groupby(['device_id','enc_app'])['enc_app'].agg(['size'])
                       .merge(train_data[['trainrow']], how='left', left_index=True, right_index=True)
                       .merge(test_data[['testrow']], how='left', left_index=True, right_index=True)
                       .reset_index())
deviceapps
# Out:
#                    device_id  enc_app  size  trainrow  testrow
# 0       -9222956879900151005      548    18   21594.0      NaN
# 1       -9222956879900151005     1096    18   21594.0      NaN
# 2       -9222956879900151005     1248    26   21594.0      NaN
# 3       -9222956879900151005     1545    12   21594.0      NaN
# 4       -9222956879900151005     1664    18   21594.0      NaN
# ...                      ...      ...   ...       ...      ...
# 2369020  9222539910510672930    17358     1       NaN  82667.0
# 2369021  9222539910510672930    17587     1       NaN  82667.0
# 2369022  9222539910510672930    18039     1       NaN  82667.0
# 2369023  9222539910510672930    18686     1       NaN  82667.0
# 2369024  9222539910510672930    18837     1       NaN  82667.0
#
# [2369025 rows x 5 columns]

# %%
# Getting the number of classes
napps = len(enc_apps.classes_)

# Getting the csr matrix for Apps
d = deviceapps.dropna(subset=['trainrow'])
Xtr_app = csr_matrix((np.ones(d.shape[0]), (d.trainrow, d.enc_app)), 
                      shape=(train_data.shape[0],napps))
d = deviceapps.dropna(subset=['testrow'])
Xte_app = csr_matrix((np.ones(d.shape[0]), (d.testrow, d.enc_app)), 
                      shape=(test_data.shape[0],napps))
print('Apps data: train shape {}, test shape {}'.format(Xtr_app.shape, Xte_app.shape))
# Out:
# Apps data: train shape (74645, 19237), test shape (112071, 19237)

# %% [markdown]
# ## 3.4. One Hot Encoding for app_labels

# %%
# First, we get the app_labels which are present in the app_events 
app_labels = app_labels.loc[app_labels.app_id.isin(app_events.app_id.unique())]
app_labels['enc_app'] = enc_apps.transform(app_labels.app_id)

# Encoding the labels
enc_labels = LabelEncoder().fit(app_labels['label_id'])
app_labels['enc_label'] = enc_labels.transform(app_labels['label_id'])

# %%
# Getting the number of classes in encoded labels
nlabels = len(enc_labels.classes_)

# Merging device apps with app labels and train and test data
devicelabels = (deviceapps[['device_id','enc_app']]
                .merge(app_labels[['enc_app','enc_label']])
                .groupby(['device_id','enc_label'])['enc_app'].agg(['size'])
                .merge(train_data[['trainrow']], how='left', left_index=True, right_index=True)
                .merge(test_data[['testrow']], how='left', left_index=True, right_index=True)
                .reset_index())

devicelabels.head()
# Out:
#              device_id  enc_label  size  trainrow  testrow
# 0 -9222956879900151005        117     1   21594.0      NaN
# 1 -9222956879900151005        120     1   21594.0      NaN
# 2 -9222956879900151005        126     1   21594.0      NaN
# 3 -9222956879900151005        138     2   21594.0      NaN
# 4 -9222956879900151005        147     2   21594.0      NaN

# %%
# Constructing a CSR matrix for labels
d = devicelabels.dropna(subset=['trainrow'])
Xtr_label = csr_matrix((np.ones(d.shape[0]), (d.trainrow, d.enc_label)), 
                      shape=(train_data.shape[0],nlabels))
d = devicelabels.dropna(subset=['testrow'])
Xte_label = csr_matrix((np.ones(d.shape[0]), (d.testrow, d.enc_label)), 
                      shape=(test_data.shape[0],nlabels))
print('Labels data: train shape {}, test shape {}'.format(Xtr_label.shape, Xte_label.shape))
# Out:
# Labels data: train shape (74645, 492), test shape (112071, 492)

# %% [markdown]
# ## 3.5. TFIDF Vectorizer for Events Hour

# %%
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Timestamp.html
# Extracting the hour at which a specific event occurred to put it in phase
events['hour'] = events['timestamp'].apply(lambda x : x.hour)

# %%
# In hourevents, we get a string of all the hours at which events were recorded for a specific device
hourevents = events.groupby("device_id")["hour"].apply(lambda x: " ".join('0'+str(s) for s in x))
hourevents = hourevents.reset_index().set_index('device_id')

# %%
# Mapping hour from hourevents to train and test data
train_data['event_hours'] = hourevents['hour']
test_data['event_hours'] = hourevents['hour']

# %%
# As there are devices which don't have any recorded events, so we fill the NaN values with '0'
train_data = train_data.fillna('0')
test_data = test_data.fillna('0')

# %%
# Tfidf vectorizer for event hours
vectorizer_hours = TfidfVectorizer()
vectorizer_hours.fit(train_data['event_hours'].values)

Xtr_hours = vectorizer_hours.transform(train_data['event_hours'].values)
Xte_hours = vectorizer_hours.transform(test_data['event_hours'].values)

print("Train shape : ",Xtr_hours.shape)
print("Test shape : ",Xte_hours.shape)
# Out:
# Train shape :  (74645, 24)
# Test shape :  (112071, 24)

# %% [markdown]
# ## 3.6. Tfidf vectorizer for Events Day

# %%
# Getting the day at which a specific event occurred from the timestamp object
events['dayofweek'] = events['timestamp'].apply(lambda x : x.dayofweek)

# %%
# In dayevents, we get a string of all the days at which events were recorded for a specific device
dayevents = events.groupby("device_id")["dayofweek"].apply(lambda x: " ".join('0'+str(s) for s in x))
dayevents = dayevents.reset_index().set_index('device_id')

# %%
# Mapping dayofweek from dayevents to train and test data
train_data['event_day'] = dayevents['dayofweek']
test_data['event_day'] = dayevents['dayofweek']

# %%
# As there are devices which don't have any recorded events, so we fill the NaN values with '0'
train_data = train_data.fillna('0')
test_data = test_data.fillna('0')

# %%
# Tfidf vectorizer for event day
vectorizer_day = TfidfVectorizer()
vectorizer_day.fit(train_data['event_day'].values)

Xtr_day = vectorizer_day.transform(train_data['event_day'].values)
Xte_day = vectorizer_day.transform(test_data['event_day'].values)

print("Train shape : ",Xtr_day.shape)
print("Test shape : ",Xte_day.shape)
# Out:
# Train shape :  (74645, 7)
# Test shape :  (112071, 7)

# %% [markdown]
# ## 3.7. TFIDF Vectorizer for Apps Active

# %%
# Now we get a list of the activity status of an app when the event was recorded
apps_active = app_events.groupby(['event_id'])['is_active'].apply(lambda x: " ".join(str(s) for s in x)).reset_index().set_index('event_id')
events['apps_active'] = apps_active['is_active']
events_apps_active = events.groupby("device_id")["apps_active"].apply(lambda x: " ".join(str(s) for s in x if str(s)!='nan'))
events_apps_active = events_apps_active.reset_index().set_index('device_id')
events_apps_active.head()
# Out:
#                                                             apps_active
# device_id
# -9222956879900151005  False False False False False False False True...
# -9222661944218806987  True False True True True True True False Fals...
# -9222399302879214035  False False False False False False False Fals...
# -9221825537663503111  False False True False False True True False F...
# -9221767098072603291  True False False False False True False True F...

# %%
# Mapping apps_active from events_apps_active to train and test data
train_data['apps_active'] = events_apps_active['apps_active']
test_data['apps_active'] = events_apps_active['apps_active']

# %%
# As there are devices which don't have any recorded events, so we fill the NaN values with '0'
train_data = train_data.fillna('0')
test_data = test_data.fillna('0')

# %%
# Tfidf vectorizer for apps_active
vectorizer_apps_active = TfidfVectorizer()
vectorizer_apps_active.fit(train_data['apps_active'].values)

Xtr_apps_active = vectorizer_apps_active.transform(train_data['apps_active'].values)
Xte_apps_active = vectorizer_apps_active.transform(test_data['apps_active'].values)
print("Train Shape ",Xtr_apps_active.shape," Test Shape ",Xte_apps_active.shape)
# Out:
# Train Shape  (74645, 2)  Test Shape  (112071, 2)

# %% [markdown]
# # 4. Classification Model for Gender

# %% [markdown]
# ## 4.1. Features used for Gender Classification
#
# 1. Phone brand
# 2. Device model
# 3. App_id
# 4. App_label
# 5. Apps_active

# %%
# Stacking all the features together
X_train_gender = hstack((Xtr_brand,
                  Xtr_model,
                  Xtr_app,
                  Xtr_label,
                  Xtr_apps_active)).tocsr()

X_test_gender = hstack((Xte_brand,
                  Xte_model,
                  Xte_app,
                  Xte_label,
                  Xte_apps_active)).tocsr()

print("X_train_gender shape ",X_train_gender.shape)
print("X_test_gender shape ",X_test_gender.shape)
# Out:
# X_train_gender shape  (74645, 21461)
# X_test_gender shape  (112071, 21461)

# %% [markdown]
# ## 4.2. Target variable
#
# 1. Gender Column in train_data is the target variable.
# 2. This is encoded using LabelEncoder.

# %%
# Getting and encoding the target variable
targetencoder = LabelEncoder().fit(train_data.gender)
y_gender = targetencoder.transform(train_data.gender)
nclasses = len(targetencoder.classes_)
print("y_gender shape ", y_gender.shape)
# Out:
# y_gender shape  (74645,)

# %%
# Saving the feature matrix to disk
from scipy.sparse import save_npz

save_npz('X_train_gender.npz',X_train_gender)
save_npz('X_test_gender.npz',X_test_gender)
np.save('y_gender',y_gender)

# %%
def plot_confusion_matrix(test_y, predict_y):
    '''
    This function buils a confusion matrix for Gender Classification
    '''
    C = confusion_matrix(test_y, predict_y)
    A =(((C.T)/(C.sum(axis=1))).T)
    B =(C/C.sum(axis=0))
   
    labels = ['F','M']
    print("-"*20, "Confusion matrix", "-"*20)
    plt.figure()
    sns.heatmap(C, annot=True, cmap="YlGnBu", fmt=".3f", xticklabels=labels, yticklabels=labels)
    plt.xlabel('Predicted Class')
    plt.ylabel('Original Class')
    plt.show()

    print("-"*20, "Precision matrix (Columm Sum=1)", "-"*20)
    plt.figure()
    sns.heatmap(B, annot=True, cmap="YlGnBu", fmt=".3f", xticklabels=labels, yticklabels=labels)
    plt.xlabel('Predicted Class')
    plt.ylabel('Original Class')
    plt.show()
    
    print("-"*20, "Recall matrix (Row sum=1)", "-"*20)
    plt.figure()
    sns.heatmap(A, annot=True, cmap="YlGnBu", fmt=".3f", xticklabels=labels, yticklabels=labels)
    plt.xlabel('Predicted Class')
    plt.ylabel('Original Class')
    plt.show()

# %%
# Loading the csr matrix from disk
from scipy.sparse import load_npz

X_gender = load_npz('X_train_gender.npz')
X_test_gender = load_npz('X_test_gender.npz')
y_gender = np.load('y_gender.npy')

# %%
# Splitting the data
X_train, X_val, y_train, y_val = \
            train_test_split(X_gender, y_gender, random_state=1026, test_size=0.2, stratify = y_gender)
print('All features Events: train shape {}, test shape {}'.format(X_train.shape, X_val.shape))
# Out:
# All features Events: train shape (59716, 21461), test shape (14929, 21461)

# %%
# Importing the modules for Neural Networks
from keras.models import Sequential, Model
from keras.layers import Dense, Dropout, Activation, BatchNormalization,Input,PReLU
from keras.optimizers import Adam, Adagrad
from keras.utils import np_utils
from tensorflow.keras.callbacks import ModelCheckpoint
# Out:
# Using TensorFlow backend.

# %%
def plot_model(history):
    '''
    This function plots the accuracy and loss.
    '''
    # Plot training & validation accuracy values
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('Model accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Test'], loc='upper left')
    plt.show()

    # Plot training & validation loss values
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('Model loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Test'], loc='upper left')
    plt.show()

# %% [markdown]
# ## 4.3. Logistic Regression for Gender Classification

# %%
# Hyperparamater tuning for Logistic Regression
alpha = [10 ** x for x in range(-6, 3)]
cv_log_error_array = []
for i in alpha:
    print("for alpha =", i)
    clf = SGDClassifier(class_weight='balanced', alpha=i, penalty='l2', loss='log', random_state=42)
    clf.fit(X_train, y_train)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(X_train, y_train)
    sig_clf_probs = sig_clf.predict_proba(X_val)
    cv_log_error_array.append(log_loss(y_val, sig_clf_probs, labels=clf.classes_, eps=1e-15))
    # to avoid rounding error while multiplying probabilites we use log-probability estimates
    print("Log Loss :",log_loss(y_val, sig_clf_probs)) 

fig, ax = plt.subplots()
ax.plot(alpha, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],str(txt)), (alpha[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()

best_alpha = np.argmin(cv_log_error_array)
clf = SGDClassifier(class_weight='balanced', alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(X_train, y_train)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(X_train, y_train)

predict_y = sig_clf.predict_proba(X_train)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(X_val)
print('For values of best alpha = ', alpha[best_alpha], "The cross validation log loss is:",log_loss(y_val, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# for alpha = 1e-06
# Log Loss : 0.6198638615432939
# for alpha = 1e-05
# Log Loss : 0.6069810361630753
# for alpha = 0.0001
# Log Loss : 0.5962992866880656
# for alpha = 0.001
# Log Loss : 0.5939450299755313
# for alpha = 0.01
# Log Loss : 0.6000712920518055
# for alpha = 0.1
# Log Loss : 0.6161494771044053
# for alpha = 1
# Log Loss : 0.6379955126446276
# for alpha = 10
# Log Loss : 0.6479022958134475
# for alpha = 100
# Log Loss : 0.6489881039195478
# For values of best alpha =  0.001 The train log loss is: 0.5803349288913595
# For values of best alpha =  0.001 The cross validation log loss is: 0.5939450299755313

# %%
# Training with the best hyperparameter i.e. alpha=0.001
clf = SGDClassifier(class_weight='balanced', alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(X_train, y_train)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(X_train, y_train)
sig_clf_probs = sig_clf.predict_proba(X_val)
# to avoid rounding error while multiplying probabilites we use log-probability estimates
print("Validation Log Loss :",log_loss(y_val, sig_clf_probs))
print("Number of missclassified point :", np.count_nonzero((sig_clf.predict(X_val)- y_val))/y_val.shape[0])
plot_confusion_matrix(y_val, sig_clf.predict(X_val.toarray()))
# Out:
# Validation Log Loss : 0.5939450299755313
# Number of missclassified point : 0.32038314689530445
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# ## 4.4. Neural Network for Gender Classification

# %%
# Converting the target variable to categorical beforing using it in the Neural Network
y_train = np_utils.to_categorical(y_train)
y_val = np_utils.to_categorical(y_val)

# %%
# Reference -> https://www.kaggle.com/c/talkingdata-mobile-user-demographics/discussion/23424

filepath="best_models/best_model_gender.hdf5"
checkpoint = ModelCheckpoint(filepath=filepath, monitor='val_loss', verbose=1, save_best_only=True, mode='auto')

input_dim = X_train.shape[1]
output_dim = 2
model = Sequential()
model.add(Dropout(0.3, input_shape=(input_dim,)))
model.add(Dense(80))
model.add(PReLU())
model.add(Dropout(0.2))
model.add(Dense(50, init='normal', activation='relu'))
model.add(PReLU())
model.add(Dropout(0.1))
model.add(Dense(output_dim, init='normal', activation='softmax'))
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dropout_1 (Dropout)          (None, 21461)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 80)                1716960
# _________________________________________________________________
# p_re_lu_1 (PReLU)            (None, 80)                80
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 80)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 50)                4050
# _________________________________________________________________
# p_re_lu_2 (PReLU)            (None, 50)                50
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 50)                0
# ...

# %%
history = model.fit(X_train, y_train, batch_size=350, epochs=7, validation_data=(X_val,y_val), verbose=0, callbacks = [checkpoint])
plot_model(history)
# Out:
# Epoch 00001: val_loss improved from inf to 0.59297, saving model to best_models/best_model_gender.hdf5
#
# Epoch 00002: val_loss improved from 0.59297 to 0.58907, saving model to best_models/best_model_gender.hdf5
#
# Epoch 00003: val_loss improved from 0.58907 to 0.58815, saving model to best_models/best_model_gender.hdf5
#
# Epoch 00004: val_loss did not improve from 0.58815
#
# Epoch 00005: val_loss did not improve from 0.58815
#
# Epoch 00006: val_loss did not improve from 0.58815
#
# Epoch 00007: val_loss did not improve from 0.58815

# %%
model.load_weights("best_models/best_model_gender.hdf5")
plot_confusion_matrix(np.argmax(y_val,axis=1), np.argmax(model.predict(X_val),axis=1))
# Out:
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# ## 4.5. Representing Results

# %%
from prettytable import PrettyTable

pt = PrettyTable()

pt.field_names = ["Model", "CV Log-loss"]
pt.add_row(["Logistic Regression", 0.59394])
pt.add_row(["Neural Network", 0.58815])
print(pt)
# Out:
# +---------------------+--------------+
# |        Model        |  CV Log-loss |
# +---------------------+--------------+
# | Logistic Regression |   0.59394    |
# |    Neural Network   |   0.58815    |
# +---------------------+--------------+

# %% [markdown]
# As the Neural Network model is giving better results, I will use the results of this model.

# %% [markdown]
# ## 4.6. Final Predictions

# %%
model.load_weights("best_models/best_model_gender.hdf5")
X_train_gender = model.predict_proba(X_gender)
X_test_gender = model.predict_proba(X_test_gender)

# %%
X_train_gender = np.argmax(X_train_gender,axis=1)
X_test_gender = np.argmax(X_test_gender,axis=1)

# %%
Xtr_gender = X_train_gender.reshape(-1,1)
Xte_gender = X_test_gender.reshape(-1,1)

# %% [markdown]
# ## 5. Regression Model for Age

# %% [markdown]
# ## 5.1. Features used for Regression
#
# 1. Phone Brand
# 2. Device Model
# 3. App_id
# 4. App_label
# 5. Apps_active
# 6. App Events Hour

# %%
# Stacking the features together that are going to be used for Linear Regression model
X_train_age = hstack((Xtr_brand,
                  Xtr_model,
                  Xtr_app,
                  Xtr_label,
                  Xtr_apps_active,
                  Xtr_hours)).tocsr()

X_test_age = hstack((Xte_brand,
                  Xte_model,
                  Xte_app,
                  Xte_label,
                  Xte_apps_active,
                  Xte_hours)).tocsr()

print("X_train_age shape ",X_train_age.shape)
print("X_test_age shape ",X_test_age.shape)
# Out:
# X_train_age shape  (74645, 21485)
# X_test_age shape  (112071, 21485)

# %% [markdown]
# ## 5.2. Target variable

# %% [markdown]
# The target variable for age is  the age column in train data

# %%
# Getting the target variable
y_age = train_data.age

# %%
# Saving the data to disk
save_npz('X_train_age.npz',X_train_age)
save_npz('X_test_age.npz',X_test_age)
np.save('y_age',y_age)

# %%
# Loading the data from disk
X_age = load_npz('X_train_age.npz')
X_test_age = load_npz('X_test_age.npz')
y_age = np.load('y_age.npy')

# %% [markdown]
# ## 5.3. Linear Regression Model for Age prediction

# %%
# Training the Linear Regression model and predicting the age
reg = LinearRegression().fit(X_age, y_age)
X_train_age = reg.predict(X_age)
X_test_age = reg.predict(X_test_age)

# %% [markdown]
# ## 5.4. Preprocessing the Age feature

# %%
# Preprocessing the output of regression model using MinMaxScaler
std_age = MinMaxScaler()
std_age.fit(X_train_age.reshape(-1,1))
Xtr_age = std_age.transform(X_train_age.reshape(-1,1))
Xte_age = std_age.transform(X_test_age.reshape(-1,1))

# %% [markdown]
# # 6. Final Classification Model

# %% [markdown]
# ## 6.1. Features
#
# 1. Phone Brand
# 2. Device model
# 3. App_id
# 4. App_label
# 5. App Events Hour
# 6. App Events Day
# 7. Apps_Active
# 8. Gender Prediction
# 9. Age Prediction

# %%
# Stacking the features together for Gender - Age group prediction
X_train = hstack((Xtr_brand,
                  Xtr_model,
                  Xtr_app,
                  Xtr_label,
                  Xtr_hours,
                  Xtr_day,
                  Xtr_apps_active,
                  Xtr_gender,
                  Xtr_age)).tocsr()

X_test = hstack((Xte_brand,
                  Xte_model,
                  Xte_app,
                  Xte_label,
                  Xte_hours,
                  Xte_day,
                  Xte_apps_active,
                  Xte_gender,
                  Xte_age)).tocsr()

print("X_train shape ",X_train.shape)
print("X_test shape ",X_test.shape)
# Out:
# X_train shape  (74645, 21494)
# X_test shape  (112071, 21494)

# %% [markdown]
# ## 6.2. Target variable
#
# 1. Target variable used in group column in train_data.
# 2. First, it is encoded using LabelEncoder

# %%
# Getting and encoding the target variable
targetencoder = LabelEncoder().fit(train_data.group)
y = targetencoder.transform(train_data.group)
nclasses = len(targetencoder.classes_)
print("y shape ", y.shape)
# Out:
# y shape  (74645,)

# %%
# Saving the sparse matrix
save_npz('X_train.npz',X_train)
save_npz('X_test.npz',X_test)
np.save('y',y)

# %%
# Loading the sparse matrix from the disk
X = load_npz('X_train.npz')
X_test = load_npz('X_test.npz')
y = np.load('y.npy')

# %% [markdown]
# ## 6.3. Logistic Regression Model

# %%
# Splitting the data
X_train, X_val, y_train, y_val = \
            train_test_split(X, y, random_state=1026, test_size=0.2, stratify = y)
print('All features Events: train shape {}, test shape {}'.format(X_train.shape, X_val.shape))
# Out:
# All features Events: train shape (59716, 21494), test shape (14929, 21494)

# %%
# Hyperparameter tuning for Logistic Regression model
alpha = [10 ** x for x in range(-6, 3)]
cv_log_error_array = []
for i in alpha:
    print("for alpha =", i)
    clf = SGDClassifier(class_weight='balanced', alpha=i, penalty='l2', loss='log', random_state=42)
    clf.fit(X_train, y_train)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(X_train, y_train)
    sig_clf_probs = sig_clf.predict_proba(X_val)
    cv_log_error_array.append(log_loss(y_val, sig_clf_probs, labels=clf.classes_, eps=1e-15))
    # to avoid rounding error while multiplying probabilites we use log-probability estimates
    print("Log Loss :",log_loss(y_val, sig_clf_probs)) 

fig, ax = plt.subplots()
ax.plot(alpha, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],str(txt)), (alpha[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()

best_alpha = np.argmin(cv_log_error_array)
clf = SGDClassifier(class_weight='balanced', alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(X_train, y_train)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(X_train, y_train)

predict_y = sig_clf.predict_proba(X_train)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(X_val)
print('For values of best alpha = ', alpha[best_alpha], "The cross validation log loss is:",log_loss(y_val, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# for alpha = 1e-06
# Log Loss : 2.351137687327667
# for alpha = 1e-05
# Log Loss : 2.307422893778867
# for alpha = 0.0001
# Log Loss : 2.262749058725163
# for alpha = 0.001
# Log Loss : 2.266105819743161
# for alpha = 0.01
# Log Loss : 2.3322904842875682
# for alpha = 0.1
# Log Loss : 2.400223642521506
# for alpha = 1
# Log Loss : 2.420492420535275
# for alpha = 10
# Log Loss : 2.4226846878110426
# for alpha = 100
# Log Loss : 2.4229089760928275
# For values of best alpha =  0.0001 The train log loss is: 2.1060981226648092
# For values of best alpha =  0.0001 The cross validation log loss is: 2.262749058725163

# %%
def plot_confusion_matrix_final(test_y, predict_y):
    '''
    This function buils a confusion matrix for final Classification of all age groups with gender
    '''
    C = confusion_matrix(test_y, predict_y)
    A =(((C.T)/(C.sum(axis=1))).T)
    B =(C/C.sum(axis=0))
   
    labels = ['F23-', 'F24-26', 'F27-28' ,'F29-32' ,'F33-42','F43+' ,'M22-' ,'M23-26','M27-28', 'M29-31' ,'M32-38' ,'M39+']
    print("-"*20, "Confusion matrix", "-"*20)
    plt.figure(figsize=(20,7))
    sns.heatmap(C, annot=True, cmap="YlGnBu", fmt=".3f", xticklabels=labels, yticklabels=labels)
    plt.xlabel('Predicted Class')
    plt.ylabel('Original Class')
    plt.show()

    print("-"*20, "Precision matrix (Columm Sum=1)", "-"*20)
    plt.figure(figsize=(20,7))
    sns.heatmap(B, annot=True, cmap="YlGnBu", fmt=".3f", xticklabels=labels, yticklabels=labels)
    plt.xlabel('Predicted Class')
    plt.ylabel('Original Class')
    plt.show()
    
    print("-"*20, "Recall matrix (Row sum=1)", "-"*20)
    plt.figure(figsize=(20,7))
    sns.heatmap(A, annot=True, cmap="YlGnBu", fmt=".3f", xticklabels=labels, yticklabels=labels)
    plt.xlabel('Predicted Class')
    plt.ylabel('Original Class')
    plt.show()

# %%
# Training the model with best hyperparamter i.e. alpha = 0.0001
clf = SGDClassifier(class_weight='balanced', alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(X_train, y_train)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(X_train, y_train)
sig_clf_probs = sig_clf.predict_proba(X_val)
# to avoid rounding error while multiplying probabilites we use log-probability estimates
print("Validation Log Loss :",log_loss(y_val, sig_clf_probs))
print("Number of missclassified point :", np.count_nonzero((sig_clf.predict(X_val)- y_val))/y_val.shape[0])
plot_confusion_matrix_final(y_val, sig_clf.predict(X_val.toarray()))
# Out:
# Validation Log Loss : 2.262749058725163
# Number of missclassified point : 0.7904079308727979
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# ## 6.4. Neural Network 1

# %%
# Converting the target variable to categorical beforing using it in the Neural Network
y = np_utils.to_categorical(y)

# %%
def model_1(input_shape):
    model = Sequential()
    model.add(Dense(256, input_dim=input_shape))
    model.add(PReLU())
    model.add(BatchNormalization())
    model.add(Dropout(0.5))
    model.add(Dense(64))
    model.add(PReLU())
    model.add(BatchNormalization())
    model.add(Dropout(0.5))
    model.add(Dense(12))
    model.add(Activation('softmax'))
    model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])
    return model

# %%
model_1(X_train.shape[1]).summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_4 (Dense)              (None, 256)               5502720
# _________________________________________________________________
# p_re_lu_3 (PReLU)            (None, 256)               256
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 256)               1024
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 64)                16448
# _________________________________________________________________
# p_re_lu_4 (PReLU)            (None, 64)                64
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 64)                256
# ...

# %%
# Reference -> https://www.kaggle.com/c/talkingdata-mobile-user-demographics/discussion/23424

import random
from scipy.sparse import load_npz
model_list = []
avg_val_loss = 0
random_seeds = random.sample(range(1, 100), 20)
for i in random_seeds:
    print("For Seed = ",i)
    print()
    X_train, X_val, y_train, y_val = train_test_split(X, y, random_state=i, test_size=0.2,stratify = y)
    filepath="best_models/NN1/best_model_"+str(i)+".hdf5"
    checkpoint = ModelCheckpoint(filepath=filepath, monitor='val_loss', verbose=1, save_best_only=True, mode='auto')
    input_shape = X_train.shape[1]
    model = model_1(input_shape)
    history = model.fit(X_train, y_train, batch_size=350, epochs=5, verbose=0, validation_data=(X_val, y_val), callbacks = [checkpoint])
    plot_model(history)
    model.load_weights("best_models/NN1/best_model_"+str(i)+".hdf5")
    predict_val = model.predict_proba(X_val)
    val_loss=log_loss(y_val, predict_val)
    print("Validation Log Loss : ",val_loss)
    model_list.append(model)
    avg_val_loss += val_loss
avg_val_loss = avg_val_loss/len(random_seeds)
print("Average Validation Log Loss = ", avg_val_loss)
# Out:
# For Seed =  36
#
#
# Epoch 00001: val_loss improved from inf to 2.37307, saving model to best_models/NN1/best_model_36.hdf5
#
# Epoch 00002: val_loss improved from 2.37307 to 2.30214, saving model to best_models/NN1/best_model_36.hdf5
#
# Epoch 00003: val_loss improved from 2.30214 to 2.25497, saving model to best_models/NN1/best_model_36.hdf5
#
# Epoch 00004: val_loss improved from 2.25497 to 2.23913, saving model to best_models/NN1/best_model_36.hdf5
#
# Epoch 00005: val_loss did not improve from 2.23913
# Validation Log Loss :  2.239125237542038
# For Seed =  21
#
#
# Epoch 00001: val_loss improved from inf to 2.39289, saving model to best_models/NN1/best_model_21.hdf5
#
# Epoch 00002: val_loss improved from 2.39289 to 2.31118, saving model to best_models/NN1/best_model_21.hdf5
#
# Epoch 00003: val_loss improved from 2.31118 to 2.25392, saving model to best_models/NN1/best_model_21.hdf5
#
# ...

# %%
# Prediction for validation data
val_pred_avg = np.zeros((X_val.shape[0],12))
for i in range(len(model_list)):
    pred = model_list[i].predict_proba(X_val)
    val_pred_avg += pred
val_pred_avg = val_pred_avg/len(model_list)

# %%
# Plotting Confusion matrix for validation data
plot_confusion_matrix_final(np.argmax(y_val,axis=1), np.argmax(val_pred_avg,axis=1))
# Out:
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# ### Prediction for Test Data using Neural Network 1 models

# %%
# Prediction for test data
test_pred_avg = np.zeros((X_test.shape[0],12))
for i in range(len(model_list)):
    pred = model_list[i].predict_proba(X_test)
    test_pred_avg += pred
test_pred_avg = test_pred_avg/len(model_list)

# %%
# Saving the predictions from Neural Network 1 to disk
np.save('TestPredictions/NN_1_Avg_test_prediction',test_pred_avg)

# %% [markdown]
# ## 6.5. Neural Network 2

# %%
def model_2(input_dim):   
    model = Sequential()
    model.add(Dropout(0.3, input_shape=(input_dim,)))
    model.add(Dense(80))
    model.add(PReLU())
    model.add(Dropout(0.2))
    model.add(Dense(50, init='normal', activation='relu'))
    model.add(PReLU())
    model.add(Dropout(0.1))
    model.add(Dense(12, init='normal', activation='softmax'))
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    return model

# %%
model_2(X_train.shape[1]).summary()
# Out:
# Model: "sequential_23"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dropout_46 (Dropout)         (None, 21494)             0
# _________________________________________________________________
# dense_67 (Dense)             (None, 80)                1719600
# _________________________________________________________________
# p_re_lu_45 (PReLU)           (None, 80)                80
# _________________________________________________________________
# dropout_47 (Dropout)         (None, 80)                0
# _________________________________________________________________
# dense_68 (Dense)             (None, 50)                4050
# _________________________________________________________________
# p_re_lu_46 (PReLU)           (None, 50)                50
# _________________________________________________________________
# dropout_48 (Dropout)         (None, 50)                0
# ...

# %%
# Reference -> https://www.kaggle.com/c/talkingdata-mobile-user-demographics/discussion/23424

model_list = []
avg_val_loss = 0
random_seeds = random.sample(range(1, 100), 20)

for i in random_seeds:
    print("For Seed ",i)
    print()
    X_train, X_val, y_train, y_val = train_test_split(X, y, random_state=i, test_size=0.2,stratify = y)
    filepath="best_models/NN2/best_model_"+str(i)+".hdf5"
    checkpoint = ModelCheckpoint(filepath=filepath, monitor='val_loss', verbose=1, save_best_only=True, mode='auto')
    input_dim = X_train.shape[1]
    model = model_2(input_dim)
    history = model.fit(X_train, y_train, batch_size=350, epochs=5, verbose=0, validation_data=(X_val, y_val), callbacks = [checkpoint])
    plot_model(history)
    model.load_weights("best_models/NN2/best_model_"+str(i)+".hdf5")
    predict_val = model.predict_proba(X_val)
    val_loss=log_loss(y_val, predict_val)
    print("Validation Log Loss : ",val_loss)
    model_list.append(model)
    avg_val_loss += val_loss
avg_val_loss = avg_val_loss/len(random_seeds)
print("Average Validation Log Loss = ", avg_val_loss)
# Out:
# For Seed  66
#
#
# Epoch 00001: val_loss improved from inf to 2.28586, saving model to best_models/NN2/best_model_66.hdf5
#
# Epoch 00002: val_loss improved from 2.28586 to 2.26030, saving model to best_models/NN2/best_model_66.hdf5
#
# Epoch 00003: val_loss improved from 2.26030 to 2.25143, saving model to best_models/NN2/best_model_66.hdf5
#
# Epoch 00004: val_loss did not improve from 2.25143
#
# Epoch 00005: val_loss did not improve from 2.25143
# Validation Log Loss :  2.251433614475488
# For Seed  23
#
#
# Epoch 00001: val_loss improved from inf to 2.28373, saving model to best_models/NN2/best_model_23.hdf5
#
# Epoch 00002: val_loss improved from 2.28373 to 2.25613, saving model to best_models/NN2/best_model_23.hdf5
#
# Epoch 00003: val_loss improved from 2.25613 to 2.24937, saving model to best_models/NN2/best_model_23.hdf5
#
# Epoch 00004: val_loss improved from 2.24937 to 2.24660, saving model to best_models/NN2/best_model_23.hdf5
#
# ...

# %%
# Predictions for validation data
val_pred_avg = np.zeros((X_val.shape[0],12))
for i in range(len(model_list)):
    pred = model_list[i].predict_proba(X_val)
    val_pred_avg += pred
val_pred_avg = val_pred_avg/len(model_list)

# %%
# Plotting confusion matrix for validation data
plot_confusion_matrix_final(np.argmax(y_val,axis=1), np.argmax(val_pred_avg,axis=1))
# Out:
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# ### Prediction for Test Data using Neural Network 2

# %%
# Predictions for test data
test_pred_avg = np.zeros((X_test.shape[0],12))
for i in range(len(model_list)):
    pred = model_list[i].predict_proba(X_test)
    test_pred_avg += pred
test_pred_avg = test_pred_avg/len(model_list)

# %%
# Saving the predictions to disk
np.save('TestPredictions/NN_2_Avg_test_prediction',test_pred_avg)

# %% [markdown]
# ## 6.6. Representing Results

# %%
# Representing results in a table
pt = PrettyTable()

pt.field_names = ["Model", " CV Log-loss"]
pt.add_row(["Logistic Regression", 2.26274])
pt.add_row(["Neural Network 1", 2.23947])
pt.add_row(["Neural Network 2", 2.24441])
print(pt)
# Out:
# +---------------------+--------------+
# |        Model        |  CV Log-loss |
# +---------------------+--------------+
# | Logistic Regression |   2.26274    |
# |   Neural Network 1  |   2.23947    |
# |   Neural Network 2  |   2.24441    |
# +---------------------+--------------+

# %% [markdown]
# ## Observations
#
# 1. Logistic Regression model gives the highest validation log loss.
# 2. I will use the Neural Network 1 and Neural Network 2 for Ensemble modeling

# %% [markdown]
# # 7. Ensemble Modeling

# %%
# Reading the data saved in disk
NN1 = np.load('TestPredictions/NN_1_Avg_test_prediction.npy')
NN2 = np.load('TestPredictions/NN_2_Avg_test_prediction.npy')

# %% [markdown]
# 1. For Model Ensembling, first I tried using all the model i.e. Logistic Regression and both the neural networks but I wasn't getting the desired results. So I experimented with the results of the neural networks only and got better solutions
# 2. Through experimentation, I found the following weight coefficients which gave the best results for Test Data.

# %%
test_pred = 0.1*NN1+0.9*NN2
predict_data = pd.DataFrame(test_pred).set_index(test_data.index)
predict_data.columns = np.unique(train_data.group)
predict_data.to_csv('submissions_final.csv')

# %%
predict_data.head()
# Out:
#                           F23-    F24-26    F27-28    F29-32    F33-42  \
# device_id
#  1002079943728939269  0.000455  0.001848  0.003356  0.010226  0.036115
# -1547860181818787117  0.002094  0.006524  0.009546  0.027018  0.066007
#  7374582448058474277  0.032108  0.058115  0.061915  0.137424  0.148980
# -6220210354783429585  0.004061  0.007716  0.006949  0.013202  0.026495
# -5893464122623104785  0.047229  0.056213  0.043569  0.061112  0.058987
#
#                           F43+      M22-    M23-26    M27-28    M29-31  \
# device_id
#  1002079943728939269  0.053298  0.003276  0.029331  0.043226  0.124902
# -1547860181818787117  0.071683  0.005581  0.043837  0.051415  0.124199
#  7374582448058474277  0.065997  0.017800  0.058147  0.055632  0.100273
# -6220210354783429585  0.039261  0.045481  0.167590  0.091289  0.175066
# -5893464122623104785  0.044063  0.093169  0.157578  0.097888  0.120708
#
#                         M32-38      M39+
# device_id
# ...

# %% [markdown]
# # 8. Kaggle Submission

# %% [markdown]
# ## 8.1. Kaggle Scores

# %%
from IPython.core.display import Image, display
display(Image('KaggleScore.png'))

# %%
display(Image('Scores.png'))

# %% [markdown]
# ## 8.2. Private Leaderboard
#
# ### Private Score = 2.24031
#
# ### Private Rank = 173

# %%
display(Image('PrivateLeaderboard.png'))

# %% [markdown]
# ## 8.3. Public Leaderboard
#
# ### Public Score = 2.23706
#
# ### Public Rank = 185

# %%
display(Image('PublicLeaderboard.png'))

# %% [markdown]
# # 9 Conclusion

# %% [markdown]
# 1. I experimented with different features that weren't used previously in the solutions available.
# 2. A large amount of Data related to Event details is missing, i.e. about 70% of both train and test data does not have Event details
# 3. Event Data is essential for predicting the correct user group without which we are left with only Phone Brand and Device Model Features.
# 4. After trying various approaches, I got a private score of 2.24031 with a rank of 173 among 1688 submissions.

# %% [markdown]
# # 10. References

# %% [markdown]
# 1. https://medium.com/analytics-vidhya/talking-data-user-demographics-19e3d15627b5 <br>
# 2. https://github.com/AbhishekAnand18/Talking_Data_User_Demographics <br>
# 3. https://www.kaggle.com/c/talkingdata-mobile-user-demographics/discussion/23424 <br>
# 4. https://github.com/yiqingyang75/kaggle-TalkingData-Mobile-User-Demographics <br>
# 5. https://github.com/jonasca/TalkingData <br>
